# %% [markdown]
# ## YARA Rule Generation Based on Pattern Engineering

# %% [markdown]
# This notebook implements a direct pattern-matching approach to generate YARA rules.
# This strategy was chosen over a Machine Learning model due to the small size and imbalanced nature of the provided input files, which made a data-driven model ineffective.
#
# The goal is to parse security indicators (such as file names and hashes) from the input files and convert them into functional YARA rules, demonstrating a practical and robust method for threat signature generation.

# %%
import pandas as pd
import csv
import os
import numpy as np
import yara
import re # is crucial for the new sanitization step to remove problematic characters.
from datetime import datetime

# %% [markdown]
# ## 1. Data Loading and Preparation
#
# Objective: Load all files from new_input_files and structure them so I can easily process the content.

# %%
# Try to import yara, handle if not available
try:
    import yara
    YARA_AVAILABLE = True
    print("yara-python available.")
except ImportError:
    YARA_AVAILABLE = False
    print("yara-python not available. Install with pip install yara-python")


def load_data_and_handle_encoding(data_dir):
    """
    Loads text content from files in a directory and handles UnicodeDecodeError.
    """
    data = {}
    
    for filename in os.listdir(data_dir):
        file_path = os.path.join(data_dir, filename)
        
        if os.path.isfile(file_path):
            label = os.path.splitext(filename)[0]
            print(f"Processing: {filename}")
            
            try:
                # Try UTF-8 first
                with open(file_path, 'r', encoding='utf-8') as f:
                    content = f.read()
                print(f"Read with UTF-8")
            except UnicodeDecodeError:
                try:
                    # Try latin-1 if UTF-8 fails
                    with open(file_path, 'r', encoding='latin-1') as f:
                        content = f.read()
                    print(f"Read with latin-1")
                except Exception as e:
                    print(f"Error Read {filename}: {e}")
                    content = ""
            except Exception as e:
                print(f" Unespected error with {filename}: {e}")
                content = ""
            
            if content:
                data[label] = content
                print(f"Loaded content: {len(content)} characters")
            else:
                print(f"Empty or unreadable file")

    print(f"\n Total files uploaded: {len(data)}")
    return data
# Out:
# yara-python available.

# %% [markdown]
# ## 2. YARA Rule Generation
#
# Objective: Analyze the contents of each file and build the YARA rule syntax.
#
# Considerations:
#
# Rules for .txt: If text files (such as Adware.txt) contain lists of strings or file names, the code must read each line and convert it into a YARA string.
#
# Rules for .csv: The CSV file likely has columns with hashes (MD5, SHA256) or signature names.

# %%
def generate_yara_rule_text(label, content):
    """
    Generates the text for a YARA rule.

    Args:
        label (str): The name of the rule, derived from the file name.
        content (str): The content of the file to be converted into YARA strings.

    Returns:
        str: A string containing the complete YARA rule syntax.
    """
    print(f"Generating rule for: {label}")

    # Create a valid YARA identifier
    yara_identifier = re.sub(r'[^a-zA-Z0-9_]', '_', label)
    yara_strings = []

    # More aggressive sanitization and consistent line splitting
    sanitized_content = re.sub(r'[\x00-\x1F\x7F-\x9F]', '', content)
    
    # Using re.split to handle various line endings more robustly
    lines = re.split(r'[\r\n]+', sanitized_content.strip())
    
    if label.lower().endswith("signatures_list"): # Adjusted condition for flexibility
        # Special handling for CSV
        if not lines:
            print("Empty CSV file")
            return ""

        csv_reader = csv.reader(lines)
        
        # Skip header if it exists
        try:
            first_row = next(csv_reader)
            if first_row and any(word in first_row[0].lower() for word in ['name', 'signature', 'hash', 'file']):
                print(f"Header detected and skipped: {first_row[0]}")
            elif first_row and first_row[0].strip():
                # Process the first row if it's not a header
                sanitized_string = first_row[0].strip()
                if sanitized_string:
                    escaped_string = sanitized_string.replace('\\', '\\\\').replace('"', '\\"')
                    yara_strings.append(f'\t$s0 = "{escaped_string}"')
        except StopIteration:
            print("Empty CSV or no data")
            return ""

        string_counter = len(yara_strings)
        for row in csv_reader:
            if row and row[0]:
                sanitized_string = row[0].strip()
                if sanitized_string:
                    escaped_string = sanitized_string.replace('\\', '\\\\').replace('"', '\\"')
                    yara_strings.append(f'\t$s{string_counter} = "{escaped_string}"')
                    string_counter += 1

    else:
        # Handling for general text files
        string_counter = 0
        for line in lines:
            cleaned_line = line.strip()
            if cleaned_line and not cleaned_line.startswith(('#', '//')):
                escaped_line = cleaned_line.replace('\\', '\\\\').replace('"', '\\"')
                yara_strings.append(f'\t$s{string_counter} = "{escaped_line}"')
                string_counter += 1

    print(f"Valid strings found: {len(yara_strings)}")

    if not yara_strings:
        print(f"No valid strings found for {label}")
        return ""

    strings_section = "\n".join(yara_strings)
    rule = f'''rule {yara_identifier} : {label} {{
    strings:
{strings_section}
    condition:
        any of them
}}

'''
    return rule

# %% [markdown]
# ## 3. Compilation and Storage
#
# Objective: Compile the generated YARA rules and save them in a .yar file.

# %%
def compile_and_save_yara_rules(rules_dict, output_dir="../output", filename="compiled_rules.yar"):
    """
    Compiles and saves YARA rules - COMPLETELY CORRECTED VERSION
    """
    print(f"\n{'='*60}")
    print(f"COMPILING AND SAVING YARA RULES")
    print(f"{'='*60}")
    
    if not rules_dict:
        print("ERROR: No rules to compile")
        return False

    # Create output directory
    if not os.path.exists(output_dir):
        os.makedirs(output_dir)
        print(f"Directory created: {output_dir}")

    # Filter empty rules and combine
    valid_rules = []
    for label, rule_text in rules_dict.items():
        if rule_text and rule_text.strip():
            valid_rules.append(rule_text)
            print(f"Valid rule included: {label}")
        else:
            print(f"Empty rule omitted: {label}")

    if not valid_rules:
        print("ERROR: No valid rules to save")
        return False

    # Combine all rules
    combined_rules = "\n".join(valid_rules)
    
    # Final sanitization
    combined_rules = re.sub(r'[\x00]', '', combined_rules)
    
    # Define output file
    output_file = os.path.join(output_dir, filename)
    
    print(f"\n📊 SUMMARY:")
    print(f"   Valid rules: {len(valid_rules)}")
    print(f"   Total size: {len(combined_rules):,} characters")
    print(f"   Destination file: {output_file}")

    try:
        # SAVE THE TEXT FILE FIRST
        with open(output_file, 'w', encoding='utf-8') as f:
            f.write(combined_rules)
        
        # Verify that it was created
        if os.path.exists(output_file):
            file_size = os.path.getsize(output_file)
            print(f"\n🎉 FILE SAVED SUCCESSFULLY!")
            print(f"   📍 Location: {os.path.abspath(output_file)}")
            print(f"   📏 Size: {file_size:,} bytes")
            print(f"   🕐 Created: {datetime.now().strftime('%Y-%m-%d %H:%M:%S')}")
        else:
            print("ERROR: The file was not created")
            return False

        # ATTEMPT TO COMPILE IF YARA IS AVAILABLE
        if YARA_AVAILABLE:
            print(f"\n🔍 Validating YARA syntax...")
            try:
                compiled_rules = yara.compile(source=combined_rules)
                print("Valid YARA syntax - Rules compiled correctly")
                
                # Save compiled version as well
                compiled_file = output_file.replace('.yar', '_compiled.yar')
                compiled_rules.save(compiled_file)
                print(f"Compiled version saved: {compiled_file}")
                
            except yara.SyntaxError as e:
                print(f"YARA syntax error: {e}")
                print("Text file saved for manual review")
            except Exception as e:
                print(f"Compilation error: {e}")
                print("Text file saved correctly")
        else:
            print("yara-python not available - Only text file was saved")

        # Show a sample of the content
        print(f"\n📄 Sample of the generated file:")
        with open(output_file, 'r', encoding='utf-8') as f:
            lines = f.readlines()[:15]
            for i, line in enumerate(lines, 1):
                print(f"   {i:2d}: {line.rstrip()}")
            if len(lines) >= 15:
                print("   ...")

        return True
        
    except Exception as e:
        print(f"UNEXPECTED ERROR: {e}")
        import traceback
        traceback.print_exc()
        return False

# %% [markdown]
# ## 4. Main function to execute all

# %%
def main_execution(data_directory):
    """
    Main function that executes the entire process
    """
    print("STARTING FULL YARA GENERATION PROCESS")
    print("="*60)
    
    # 1. Load data
    print("\n 1. LOADING DATA...")
    raw_data = load_data_and_handle_encoding(data_directory)
    
    if not raw_data:
        print(" No data loaded. Process terminated.")
        return False
    
    print(f"Files loaded: {list(raw_data.keys())}")
    
    # 2. Generate YARA rules
    print("\n 2. GENERATING YARA RULES...")
    yara_rules_dict = {}
    
    for label, content in raw_data.items():
        rule_text = generate_yara_rule_text(label, content)
        if rule_text:
            yara_rules_dict[label] = rule_text
    
    print(f"\n Rules generated: {len(yara_rules_dict)}/{len(raw_data)}")
    
    if not yara_rules_dict:
        print(" No valid rules generated. Process terminated.")
        return False
    
    # 3. Compile and save
    print("\n 3. COMPILING AND SAVING...")
    success = compile_and_save_yara_rules(yara_rules_dict)
    
    if success:
        print("\n PROCESS COMPLETED SUCCESSFULLY!")
    else:
        print("\n Error in the compilation process")
    
    return success

# %% [markdown]
# ## 5. Execute the whole process

# %%
if __name__ == "__main__":
    # My path to the data directory
    data_directory = '/Users/dianaterraza/Desktop/data_scientist_yara_project/new_input_files'
    
    # Verify that the directory exists
    if not os.path.exists(data_directory):
        print(f" ERROR: Directory not found: {data_directory}")
        print("Please, update the 'data_directory' variable with the correct path.")
    else:
        main_execution(data_directory)
# Out:
# STARTING FULL YARA GENERATION PROCESS
# ============================================================
#
#  1. LOADING DATA...
# Processing: Backdoor.txt
# Read with latin-1
# Loaded content: 1240170 characters
# Processing: Dialer.txt
# Read with latin-1
# Loaded content: 8244 characters
# Processing: Behavior.txt
# Read with latin-1
# Loaded content: 953526 characters
# Processing: BrowserModifier.txt
# Read with latin-1
# Loaded content: 47888 characters
# Processing: Adware.txt
# Read with latin-1
# Loaded content: 95012 characters
# Processing: Microsoft_Defender_All_signatures_list.csv
# Read with UTF-8
# Loaded content: 11161500 characters
# Processing: Constructor.txt
# Read with latin-1
# Loaded content: 35412 characters
#
#  Total files uploaded: 7
# Files loaded: ['Backdoor', 'Dialer', 'Behavior', 'BrowserModifier', 'Adware', 'Microsoft_Defender_All_signatures_list', 'Constructor']
#
#  2. GENERATING YARA RULES...
# Generating rule for: Backdoor
# Valid strings found: 1
# Generating rule for: Dialer
# Valid strings found: 1
# Generating rule for: Behavior
# Valid strings found: 1
# Generating rule for: BrowserModifier
# Valid strings found: 1
# Generating rule for: Adware
# Valid strings found: 1
# Generating rule for: Microsoft_Defender_All_signatures_list
# Header detected and skipped: signature
# Valid strings found: 0
# No valid strings found for Microsoft_Defender_All_signatures_list
# Generating rule for: Constructor
# Valid strings found: 1
#
#  Rules generated: 6/7
#
#  3. COMPILING AND SAVING...
#
# ============================================================
# COMPILING AND SAVING YARA RULES
# ============================================================
# Valid rule included: Backdoor
# Valid rule included: Dialer
# Valid rule included: Behavior
# Valid rule included: BrowserModifier
# Valid rule included: Adware
# Valid rule included: Constructor
#
# 📊 SUMMARY:
#    Valid rules: 6
#    Total size: 1,108,881 characters
#    Destination file: ../output/compiled_rules.yar
#
# 🎉 FILE SAVED SUCCESSFULLY!
#    📍 Location: /Users/dianaterraza/Desktop/data_scientist_yara_project/output/compiled_rules.yar
#    📏 Size: 1,108,893 bytes
#    🕐 Created: 2025-08-15 17:56:42
#
# 🔍 Validating YARA syntax...
# YARA syntax error: line 3: syntax error, unexpected end of file, expecting text string
# Text file saved for manual review
#
# 📄 Sample of the generated file:
#     1: rule Backdoor : Backdoor {
#     2:     strings:
#     3: 	$s0 = "ÿþWorm:Win32/WootbotBackdoor:Win32/HupigonBackdoor:Win32/Amitis.EBackdoor:Win32/Antilam.SBackdoor:Win32/Banger.FBackdoor:Win32/Beastdoor.COBackdoor:Win32/Beastdoor.CPBackdoor:Win32/Beastdoor.CQBackdoor:Win32/Beastdoor.CXBackdoor:Win32/Beastdoor.DABackdoor:Win32/Beastdoor.DBBackdoor:Win32/Beastdoor.DDBackdoor:Win32/BifroseBackdoor:Win32/BionetBackdoor:Win32/Delf.ZKBackdoor:Win32/DSNXBackdoor:Win32/Ferat.BBackdoor:Win32/Gift.DBackdoor:Win32/G_Door.UBackdoor:Win32/InfecDoorBackdoor:Win32/Jeemp.GBackdoor:Win32/Kamikaze.BBackdoor:Win32/Lanfiltrator.RBackdoor:Win32/OptixBackdoor:Win32/Berbew.DXBackdoor:Win32/PoebotBackdoor:Win32/RobobotBackdoor:Win32/Slackbot.EBackdoor:Win32/Aimbot.AWBackdoor:Win32/Flux.JBackdoor:Win32/Fluxdor.BBackdoor:Win32/Fluxdor.CBackdoor:Win32/Surila.RBackdoor:Win32/VB.ZTBackdoor:Win32/Bionet.GBackdoor:Win32/BNLite.ABackdoor:Win32/DSNX.GBackdoor:Win32/Hupigon.TLBackdoor:Win32/Hupigon.TMBackdoor:Win32/Hupigon.TNBackdoor:Win32/Amitis.FBackdoor:Win32/Amitis.GBackdoor:Win32/Amitis.HBackdoor:Win32/Amitis.IBackdoor:Win32/Amitis.JBackdoor:Win32/Amitis.KBackdoor:Win32/Bancodor.AABackdoor:Win32/Bancodor.ACBackdoor:Win32/Bancodor.AGBackdoor:Win32/Beastdoor.DEBackdoor:Win32/Beastdoor.DFBackdoor:Win32/Beastdoor.DGBackdoor:Win32/Beastdoor.DHBackdoor:Win32/Beastdoor.DIBackdoor:Win32/Beastdoor.DJBackdoor:Win32/Beastdoor.DKBackdoor:Win32/Blackhole.EBackdoor:Win32/CyberSpy.EBackdoor:Win32/Feap.ABackdoor:Win32/Gobot.AIBackdoor:Win32/Hupigon.GWBackdoor:Win32/Jix.ABackdoor:Win32/Litmus.AFBackdoor:Win32/Litmus.AGBackdoor:Win32/Litmus.AHBackdoor:Win32/Litmus.AIBackdoor:Win32/Prexot.ABackdoor:Win32/Small.VVBackdoor:Win32/Small.VWBackdoor:Win32/Small.VXBackdoor:Win32/Surila.SBackdoor:Win32/Surila.TBackdoor:Win32/Tompai.EBackdoor:Win32/Verify.LBackdoor:Win32/Wollf.HBackdoor:Win32/Berbew.IBackdoor:Win32/Dumador.JCBackdoor:Win32/Dumador.JDBackdoor:Win32/Gobot.GBackdoor:Win32/Nuclear.TBackdoor:Win32/PcClient.WBackdoor:Win32/Spookdoor.IBackdoor:Win32/Surila.UBackdoor:Win32/VB.ZUBackdoor:Win32/VBbot.PBackdoor:Win32/Verify.MBackdoor:Win32/Winshell.LBackdoor:Win32/Brabot.CBackdoor:Win32/Banito.HBackdoor:Win32/DSNX.0_4Backdoor:Win32/Delf.VPBackdoor:Win32/Codbot.BWBackdoor:Win32/RCServ.CBackdoor:Win32/IrcContact.GBackdoor:Win32/DSNX.FBackdoor:Win32/Mytobot.EBackdoor:Win32/Mytobot.FBackdoor:Win32/Wisdoor.CCBackdoor:Win32/Wisdoor.CDBackdoor:Win32/Wisdoor.CFBackdoor:Win32/Bandok.EBackdoor:Win32/Banito.EBackdoor:Win32/Banito.VBackdoor:Win32/Banito.FBackdoor:Win32/Banito.OBackdoor:Win32/Banito.WBackdoor:Win32/Banito.XBackdoor:Win32/Banito.YBackdoor:Win32/Banito.ZBackdoor:Win32/Banito.ABBackdoor:Win32/Banito.ADBackdoor:Win32/Banito.AEBackdoor:Win32/Banito.AFBackdoor:Win32/Banito.AGBackdoor:Win32/Banito.AIBackdoor:Win32/Banito.AJBackdoor:Win32/Banito.ALBackdoor:Win32/Banito.AKBackdoor:Win32/WisdoorBackdoor:Win32/Wisdoor.CJBackdoor:Win32/Wisdoor.CKBackdoor:Win32/Wisdoor.CLBackdoor:Win32/Wisdoor.CMBackdoor:Win32/Wisdoor.CNBackdoor:Win32/Wisdoor.COBackdoor:Win32/Wisdoor.CHBackdoor:Win32/Wisdoor.CPBackdoor:Win32/Wisdoor.CQBackdoor:Win32/Wisdoor.CRBackdoor:Win32/Wisdoor.CSBackdoor:Win32/Wisdoor.CTBackdoor:Win32/Wisdoor.CUBackdoor:Win32/Wisdoor.CVBackdoor:Win32/Wisdoor.CWBackdoor:Win32/Wisdoor.CXBackdoor:Win32/Wisdoor.CYBackdoor:Win32/Wisdoor.CZBackdoor:Win32/Wisdoor.DABackdoor:Win32/Wisdoor.DBBackdoor:Win32/Wisdoor.DCBackdoor:Win32/Wisdoor.DDBackdoor:Win32/Wisdoor.DEBackdoor:Win32/Wisdoor.DFBackdoor:Win32/Wisdoor.DGBackdoor:Win32/Wisdoor.DHBackdoor:Win32/Wisdoor.DIBackdoor:Win32/Wisdoor.DJBackdoor:Win32/Wisdoor.CIBackdoor:Win32/Wisdoor.CGBackdoor:Win32/Wisdoor.DKBackdoor:Win32/Wisdoor.DLBackdoor:Win32/Prorat.ABBackdoor:Win32/Flux.IBackdoor:Win32/Hersive.ABackdoor:Win32/Oscarbot.CBackdoor:Win32/Robobot.UBackdoor:Win32/Pinteep.ABackdoor:Win32/Pinteep.BBackdoor:Win32/Pinteep.CBackdoor:Win32/Pinteep.DBackdoor:Win32/Pinteep.EBackdoor:Win32/Pinteep.FBackdoor:Win32/Pinteep.GBackdoor:Win32/PcClient.APBackdoor:Win32/PcClient.AP.dllBackdoor:Win32/PcC ...
#     4:     condition:
#     5:         any of them
#     6: }
#     7:
#     8:
#     9: rule Dialer : Dialer {
#    10:     strings:
#    11: 	$s0 = "ÿþDialer:Win32/AcontiDialer:Win32/ActiveStripPlayerDialer:Win32/AdultChatDialer:Win32/LiveGirlsDialer:Win32/CoulombDialer:Win32/TippsDialer:Win32/RASDialDialer:Win32/PhoneDialDialer:Win32/DialXSDialer:Win32/EGroup.ADialer:Win32/EGroup.IDialer:Win32/EZ123Dialer:Win32/FSiteDialer:Win32/GoinDialer:Win32/HolysticDialer:Win32/EGroup.CDialer:Win32/EGroup.GDialer:Win32/LiveshowsDialer:Win32/MaConnectDialer:Win32/MediaChargerDialer:Win32/MoneyTreeDialer:Win32/SunInfoConnectDialer:Win32/PrivateAccessPluginDialer:Win32/StripPlayerDialer:Win32/DutchDialer:Win32/TScashDialer:Win32/MyworldDialer:Win32/Tibs.BDialer:Win32/TibsDialer:Win32/CashDialDialer:Win32/WebDialDialer:Win32/MostrarDialer:Win32/EGroup.EDialer:Win32/Axis.ADialer:Win32/CABDialDialer:Win32/SaristarDialer:Win32/SysWebTelecomIntDialer:Win32/WebRecommendedDialer:Win32/DialPlatform.ADialer:Win32/Unclassfied.ADialer:Win32/XpehbamDialer:Win32/GXBPluginDialer:Win32/EconopornDialer:Win32/SwitchDialer:Win32/SoftTecDialer:Win32/PornDialerDialer:Win32/EPluginDialer:Win32/TCWDialer:Win32/SysdxvidDialer:Win32/AccessSpecialDialer:Win32/MaxdDialer:Win32/CCAccessDialer:Win32/PlsexDialer:Win32/Small.AYLDialer:Win32/GlobalPremiumDialer:Win32/PornDialer.GDialer:Win32/CarpeDiemDialer:Win32/DialuiDialer:Win32/Axis.BDialer:Win32/WebDiallerDialer:Win32/TrafficadvanceDialer:Win32/RapidoDialer:Win32/DlStwoyleDialer:Win32/AdialerDialer:Win32/DialPlatform.BDialer:Win32/DialerHubDialer:Win32/Adialer.genDialer:Win32/DialXLiteDialer:Win32/RiprovaDialer:Win32/AcceccorDialer:Win32/NetCollexDialer:Win32/IPRSDialer:Win32/GBDialDialer:Win32/UlubioneDialer:Win32/HolistycDialer:Win32/AsianRawDialer:Win32/KotuDialer:Win32/UDISDialer:Win32/PagomDialer:Win32/IDialerDialer:Win32/WebPassDialer:Win32/ConnettiDialer:Win32/UltimateDialerDialer:Win32/DapsolDialer:Win32/MastaCashDialer:HTML/PornDial12.drDialer:Win32/EnergyFactor.ADialer:Win32/Adialer.ADialer:Win32/Adialer.BDialer:Win32/Adialer.CDialer:Win32/Adialer.DDialer:Win32/Adialer.EDialer:Win32/Intexus.ADialer:Win32/Obfp.ADialer:Win32/AdultChat.ADialer:Win32/Lusval.ADialer:Win32/AdultChat.BDialer:Win32/Coulomb.ADialer:Win32/CyberBill.ADialer:Win32/Webcont.ADialer:Win32/PornDialer.JFDialer:Win32/InstantAccessDialer:Win32/WebDial.ADialer:Win32/PornDialer.CENDialer:Win32/PornDialer.LOSDialer:Win32/Egroupinstantaccess.IADialer:Win32/PornDialer.ISNDialer:Win32/EgroupsexdialDialer:Win32/WebDial.BDialer:Win32/KelurfsDialer:Win32/XeighDialer:Win32/ScomDialer:Win32/Adialer.FDialer:Win32/EGroupInstantAccessDialer:Win32/PornDialer.HDialer:Win32/Tring.ADialer:Win32/Adialer.GDialer:VBS/PornDialerDialer:Win32/Obfp.BDialer:Win32/TopexDialer:Win32/WebdialerDialer:Win32/RanfructDialer:Win32/Illethrit.ADialer:Win32/AccepisDialer:Win32/Rucsis.ADialer:Win32/Rinorp.ADialer:Win32/ChargitDialer:Win32/UnifiedDialer:Win32/AdultcontDialer:Win32/LintissDialer:Win32/Adialer.HDialer:WinCE/Terdial.ADialer:Win32/XDialer.ADialer:Win32/Adialer.IDialer:Win32/Adialer.JDialer:Win32/Adialer.KDialer:Win32/Adialer.LDialer:Win32/AccesoprivadoDialer:Win32/BloiscomDialer:Win32/PornDialer.ADialer:Win32/PornDialer.BDialer:Win32/PornDialer.MTBDialer:Win32/XDialerDialer:WinCE/TerdialDialer:HTML/PornDial12Dialer:Win32/RucsisDialer:Win32/LusvalDialer:Win32/IllethritDialer:Win32/BillDialerDialer:Win32/PornDialDialer:Win32/IntexusDialer:Win32/EGroupDialer:Win32/TringDialer:Win32/CyberBillDialer:Win32/EnergyFactorDialer:Win32/ContentBrowserDialer:Win32/RinorpDialer:Win32/UnclassfiedDialer:AndroidOS/MultiverzeDialer:Win32/WebcontDialer:Win32/AxisDialer:Win32/ObfpDialer:Unix/MultiverzeDialer:Win32/PornDialer!pzDialer:Win32/InstantAccess!pzDialer:Win32/Adialer!pzDialer:Win32/Webdialer!pzDialer:Win32/CarpeDiem!pzDialer:Win32/Riprova!pzDialer:Win32/Topex!pzDialer:Win32/Coulomb!pzDialer:Win32/Multiverze"
#    12:     condition:
#    13:         any of them
#    14: }
#    15:
#    ...
#
#  PROCESS COMPLETED SUCCESSFULLY!
